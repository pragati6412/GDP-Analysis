# %%
import pandas as pd

# %%
df=pd.read_csv('GDP.csv')

# %%
df.isnull()
# Out:
#        Country Name  Country Code   Year  Value
# 0             False         False  False  False
# 1             False         False  False  False
# 2             False         False  False  False
# 3             False         False  False  False
# 4             False         False  False  False
# ...             ...           ...    ...    ...
# 11502         False         False  False  False
# 11503         False         False  False  False
# 11504         False         False  False  False
# 11505         False         False  False  False
# 11506         False         False  False  False
#
# [11507 rows x 4 columns]

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df['Country Name']
# Out:
# 0        Arab World
# 1        Arab World
# 2        Arab World
# 3        Arab World
# 4        Arab World
#             ...
# 11502      Zimbabwe
# 11503      Zimbabwe
# 11504      Zimbabwe
# 11505      Zimbabwe
# 11506      Zimbabwe
# Name: Country Name, Length: 11507, dtype: object

# %%
df['Country Name'].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
# ...

# %%
df
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %%
l=df['Country Name'].unique()
list1=[]
for i in range(len(l)):
    df1=df[df['Country Name']==l[i]]
    df2=df1.values
    list1.append(0.0)
    for j in range(1,len(df2)):
        prev=df2[j-1][3]
        curr=df2[j][3]
        x1=float(str(((curr-prev)/prev)*100)[0:5])
        list1.append(x1)
df=df.assign(GDP_growth=list1)

# %%
df
# Out:
#       Country Name Country Code  Year         Value  GDP_growth
# 0       Arab World          ARB  1968  2.576068e+10       0.000
# 1       Arab World          ARB  1969  2.843420e+10      10.370
# 2       Arab World          ARB  1970  3.138550e+10      10.370
# 3       Arab World          ARB  1971  3.642691e+10      16.060
# 4       Arab World          ARB  1972  4.331606e+10      18.910
# ...            ...          ...   ...           ...         ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10      17.720
# 11503     Zimbabwe          ZWE  2013  1.545177e+10       8.490
# 11504     Zimbabwe          ZWE  2014  1.589105e+10       2.842
# 11505     Zimbabwe          ZWE  2015  1.630467e+10       2.602
# 11506     Zimbabwe          ZWE  2016  1.661996e+10       1.933
#
# [11507 rows x 5 columns]

# %%
df.groupby('Country Name').mean()['GDP_growth'].sort_values(ascending=False).head(50)
# Out:
# Country Name
# Cayman Islands                                 108.350000
# Equatorial Guinea                               22.317830
# Nauru                                           20.655800
# Iraq                                            18.078634
# Oman                                            17.680462
# Qatar                                           17.358383
# Switzerland                                     16.102255
# Cambodia                                        14.904744
# Myanmar                                         14.210824
# Maldives                                        14.043000
# Saudi Arabia                                    13.732082
# Bosnia and Herzegovina                          13.004478
# Vietnam                                         12.663531
# Botswana                                        12.370614
# Indonesia                                       12.152100
# Korea, Rep.                                     12.114158
# ...
