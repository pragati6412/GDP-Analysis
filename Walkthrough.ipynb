# %%
import pandas as pd
df=pd.read_csv('gdp.csv')

# %%
df
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %% [markdown]
# ### Description of each column

# %%
df['Country Name'].describe()
# Out:
# count                    11507
# unique                     256
# top       Hong Kong SAR, China
# freq                        57
# Name: Country Name, dtype: object

# %%
df['Country Code'].describe()
# Out:
# count     11507
# unique      256
# top         HKG
# freq         57
# Name: Country Code, dtype: object

# %%
df['Year'].describe()
# Out:
# count    11507.000000
# mean      1991.265230
# std         15.886648
# min       1960.000000
# 25%       1978.000000
# 50%       1993.000000
# 75%       2005.000000
# max       2016.000000
# Name: Year, dtype: float64

# %%
df['Year'].max()
# Out:
# 2016

# %% [markdown]
# ### For India

# %%
df[df['Country Name']=='India']['Value'].describe()
# Out:
# count    5.700000e+01
# mean     5.093519e+11
# std      6.167624e+11
# min      3.653593e+10
# 25%      9.715922e+10
# 50%      2.753114e+11
# 75%      5.080690e+11
# max      2.263792e+12
# Name: Value, dtype: float64

# %%
df1=df[df['Country Name']=='India']

# %%
df1.groupby('Year').sum()['Value'].plot(kind='bar',figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df1.plot(kind='line',x='Year',y='Value',title="India's GDP",figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':"India's GDP"}, xlabel='Year'>

# %% [markdown]
# ### For Arab World

# %%
df1=df[df['Country Name']=='Arab World']

# %%
df1.plot(kind='line',x='Year',y='Value',legend=False,grid=True,xlabel='YEARS',ylabel='GDP',title='Year wise GDP of Arab World',
        figsize=(15,6))
# Out:
# <AxesSubplot:title={'center':'Year wise GDP of Arab World'}, xlabel='YEARS', ylabel='GDP'>
